# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from statsmodels.formula.api import ols

# %%
df= pd.read_csv('C:/Users/DELL/Desktop/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
x = df['grade']
y = df['sqft_living']

# %%
results = ols("sqft_living ~  grade + bedrooms + floors", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sqft_living   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                 1.588e+04
# Date:                Sun, 09 Jul 2023   Prob (F-statistic):               0.00
# Time:                        15:52:41   Log-Likelihood:            -1.6554e+05
# No. Observations:               21613   AIC:                         3.311e+05
# Df Residuals:                   21609   BIC:                         3.311e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2078.7756     11.414    182.119      0.000    2056.403    2101.149
# ...

# %%
results = ols("price ~  grade + bedrooms + floors", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     5996.
# Date:                Sun, 09 Jul 2023   Prob (F-statistic):               0.00
# Time:                        17:27:30   Log-Likelihood:            -3.0106e+05
# No. Observations:               21613   AIC:                         6.021e+05
# Df Residuals:                   21609   BIC:                         6.022e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.044e+05   6033.587    100.165      0.000    5.93e+05    6.16e+05
# ...

# %%
"y_hat = 2078.7756 + 585.9250grade + 320.3987bedroom + 0.7522floors"

# %%
2078.7756+585.9250*7+320.3981*3+0.7522*1
# Out:
# 7142.197099999999

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0 -0.398737  -1.447464         1180  \
# 1  6414100192 2014-12-09  538000.0 -0.398737   0.175607         2570
# 2  5631500400 2015-02-25  180000.0 -1.473959  -1.447464          770
# 3  2487200875 2014-12-09  604000.0  0.676485   1.149449         1960
# 4  1954400510 2015-02-18  510000.0 -0.398737  -0.149007         1680
#
#    sqft_lot  floors waterfront view  ...  sqft_lot15  year  month  day
# 0      5650     1.0          0    0  ...        5650  2014     10   13  \
# 1      7242     2.0          0    0  ...        7639  2014     12    9
# 2     10000     1.0          0    0  ...        8062  2015      2   25
# 3      5000     1.0          0    0  ...        5000  2014     12    9
# 4      8080     1.0          0    0  ...        7503  2015      2   18
#
#    log_price  total_bathrooms  log_sqft_living  log_sqft_lot  multi_floor
# ...

# %%
pred_vals = results.predict(df[['grade','bedrooms','floors']])

# %%
pred_vals
# Out:
# 0        1624.337197
# 1        1625.089441
# 2         781.360906
# 3        1968.837008
# 4        2122.813676
#             ...
# 21608    2124.318166
# 21609    2468.065732
# 21610    1280.589630
# 21611    2123.565921
# 21612    1280.589630
# Length: 21613, dtype: float64

# %%
res = pd.concat([pred_vals.to_frame().rename(columns={0:'y_hat'}),df['sqft_living']], axis=1)

# %%
res
# Out:
#              y_hat  sqft_living
# 0      1624.337197         1180
# 1      1625.089441         2570
# 2       781.360906          770
# 3      1968.837008         1960
# 4      2122.813676         1680
# ...            ...          ...
# 21608  2124.318166         1530
# 21609  2468.065732         2310
# 21610  1280.589630         1020
# 21611  2123.565921         1600
# 21612  1280.589630         1020
#
# [21613 rows x 2 columns]

# %%
res['error'] = res['y_hat'] - res['sqft_living']

# %%
res.head(1)
# Out:
#          y_hat  sqft_living       error
# 0  1624.337197         1180  444.337197

# %%
res['sq_error'] = res['error']**2

# %%
np.sqrt(res['sq_error'].mean())
# Out:
# 513.0700296530641

# %%
df.describe()
# Out:
#                  id                           date         price
# count  2.161300e+04                          21613  2.161300e+04  \
# mean   4.580302e+09  2014-10-29 04:38:01.959931648  5.400881e+05
# min    1.000102e+06            2014-05-02 00:00:00  7.500000e+04
# 25%    2.123049e+09            2014-07-22 00:00:00  3.219500e+05
# 50%    3.904930e+09            2014-10-16 00:00:00  4.500000e+05
# 75%    7.308900e+09            2015-02-17 00:00:00  6.450000e+05
# max    9.900000e+09            2015-05-27 00:00:00  7.700000e+06
# std    2.876566e+09                            NaN  3.671272e+05
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors
# count  2.161300e+04  2.161300e+04  21613.000000  2.161300e+04  21613.000000  \
# mean   6.575142e-19  2.104045e-17   2079.899736  1.510697e+04      1.494309
# min   -3.624404e+00 -2.745920e+00    290.000000  5.200000e+02      1.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(res['error'])
# Out:
# (array([2.0000e+00, 2.0000e+00, 3.1000e+01, 1.7430e+03, 1.9765e+04,
#         6.9000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-8043.77667215, -6205.46585125, -4367.15503034, -2528.84420944,
#          -690.53338854,  1147.77743237,  2986.08825327,  4824.39907417,
#          6662.70989508,  8501.02071598, 10339.33153688]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['sqft_living'])
# Out:
# (array([7.5690e+03, 1.0681e+04, 2.8140e+03, 4.4100e+02, 7.7000e+01,
#         2.4000e+01, 2.0000e+00, 3.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([  290.,  1615.,  2940.,  4265.,  5590.,  6915.,  8240.,  9565.,
#         10890., 12215., 13540.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['grade'],res['error'])

# %%
import scipy.stats as stats
fig=plt.figure()
ax=fig.add_subplot(111)
stats.probplot(res['error'], dist='norm', plot=ax)
# Out:
# ((array([-3.99703558, -3.78181236, -3.66408326, ...,  3.66408326,
#           3.78181236,  3.99703558]),
#   array([-8043.77667215, -6400.17612671, -5732.00501897, ...,
#           1630.5188791 ,  1651.27112399, 10339.33153688])),
#  (494.7951207842268, -1.386147219386906e-12, 0.9642095948123501))

# %%
import statsmodels.api as sm

# %%
fig,ax=plt.subplots(figsize=(12,8))
fig=sm.graphics.influence_plot(results, ax=ax, criterion='cook')

# %%
fig,ax=plt.subplots(figsize=(12,8))
fig=sm.graphics.influence_plot(results, ax=ax, criterion='DFFITS')

# %%
infl=results.get_influence()
print(infl.summary_frame())
# Out:
#        dfb_Intercept  dfb_grade  dfb_bedrooms  dfb_floors       cooks_d
# 0          -0.005945   0.000499      0.001194    0.004352  1.651548e-05  \
# 1          -0.012211  -0.012290     -0.002913    0.016849  1.242428e-04
# 2          -0.000087   0.000110      0.000156    0.000043  2.354246e-08
# 3          -0.000120   0.000053     -0.000111    0.000088  9.479032e-09
# 4          -0.008351  -0.005425      0.003062    0.006885  2.370067e-05
# ...              ...        ...           ...         ...           ...
# 21608       0.020064   0.006845      0.004581   -0.023605  1.606529e-04
# 21609       0.001144   0.000704     -0.001257   -0.001874  2.481892e-06
# 21610       0.003422   0.002132      0.004781   -0.004704  1.500424e-05
# 21611       0.003898  -0.000193      0.003827   -0.006323  2.655880e-05
# 21612       0.003422   0.002132      0.004781   -0.004704  1.500424e-05
#
#        standard_resid  hat_diag  dffits_internal  student_resid    dffits
# ...

# %%
infl.summary_frame()
# Out:
#        dfb_Intercept  dfb_grade  dfb_bedrooms  dfb_floors       cooks_d
# 0          -0.005945   0.000499      0.001194    0.004352  1.651548e-05  \
# 1          -0.012211  -0.012290     -0.002913    0.016849  1.242428e-04
# 2          -0.000087   0.000110      0.000156    0.000043  2.354246e-08
# 3          -0.000120   0.000053     -0.000111    0.000088  9.479032e-09
# 4          -0.008351  -0.005425      0.003062    0.006885  2.370067e-05
# ...              ...        ...           ...         ...           ...
# 21608       0.020064   0.006845      0.004581   -0.023605  1.606529e-04
# 21609       0.001144   0.000704     -0.001257   -0.001874  2.481892e-06
# 21610       0.003422   0.002132      0.004781   -0.004704  1.500424e-05
# 21611       0.003898  -0.000193      0.003827   -0.006323  2.655880e-05
# 21612       0.003422   0.002132      0.004781   -0.004704  1.500424e-05
#
#        standard_resid  hat_diag  dffits_internal  student_resid    dffits
# ...

# %%
categorical_features = ['condition','yr_built','yr_renovated']
numerical_features = ['price','sqft_above','sqft_basement']
target = 'id'

# %%
# split data in train / test
X_train, X_test, y_train, y_test = train_test_split(df[categorical_features + numerical_features]
                                                    ,df[target],
                                                    test_size = 0.3, random_state=1234)

# %%
# define transformers
cat_transformer = Pipeline(steps = [('onehot', OneHotEncoder(handle_unknown='ignore'))])
num_transformer = Pipeline(steps = [('scaler', StandardScaler())])

# %%
# building processor
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, categorical_features),
                                                 ('num', num_transformer, numerical_features)])

# %%
linear_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
linear_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['condition', 'yr_built',
#                                                    'yr_renovated']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['price', 'sqft_above',
#                                                    'sqft_basement'])])),
#                 ('regressor', LinearRegression())])

# %%
pred = linear_regression.predict(X_test)

# %%
pred
# Out:
# array([4.52763451e+09, 4.26043388e+09, 4.89791997e+09, ...,
#        5.28403524e+09, 4.72343208e+09, 4.51009427e+09])

# %%
np.sqrt(mean_squared_error(pred,y_test))
# Out:
# 2874392877.541238

# %%
ridge_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Ridge(alpha=3.0))
])

# %%
ridge_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['condition', 'yr_built',
#                                                    'yr_renovated']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['price', 'sqft_above',
#                                                    'sqft_basement'])])),
#                 ('regressor', Ridge(alpha=3.0))])

# %%
pred_ridge = ridge_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(pred_ridge,y_test))
# Out:
# 2869777021.223097

# %%
lasso_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Lasso(alpha=1.0))
])

# %%
lasso_regression.fit(X_train, y_train)
# Out:
# e:\python\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4360764852654553e+22, tolerance: 1.2538452759928482e+19
#   model = cd_fast.sparse_enet_coordinate_descent(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['condition', 'yr_built',
#                                                    'yr_renovated']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
# ...

# %%
lasso_pred = lasso_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(lasso_pred, y_test))
# Out:
# 2874404269.8354597

# %%
elasticnet_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', ElasticNet(alpha=1.0, l1_ratio=0.2))
])

# %%
elasticnet_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['condition', 'yr_built',
#                                                    'yr_renovated']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['price', 'sqft_above',
#                                                    'sqft_basement'])])),
#                 ('regressor', ElasticNet(l1_ratio=0.2))])

# %%
elasticnet_pred = elasticnet_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(elasticnet_pred, y_test))
# Out:
# 2869622023.128623

# %%
y_test
# Out:
# 12432    9414610240
# 7793      251300110
# 13435    7937900220
# 1821     1771110640
# 12449    3905100310
#             ...
# 2596     8056000075
# 21161    8564860280
# 20133    5137800130
# 11130    9557300560
# 16762    6669080020
# Name: id, Length: 6484, dtype: int64

# %%
X_test
# Out:
#        condition  yr_built  yr_renovated      price  sqft_above  sqft_basement
# 12432          4      1976             0   485000.0        1330            700
# 7793           3      1988             0   358000.0        2510              0
# 13435          3      2000             0   716500.0        3630              0
# 1821           4      1978             0   367500.0        1160            500
# 12449          3      1994             0   544000.0        2030              0
# ...          ...       ...           ...        ...         ...            ...
# 2596           3      1987             0  1065000.0        1890              0
# 21161          3      2013             0   459990.0        2680              0
# 20133          3      2006             0   388500.0        2718              0
# 11130          4      1973             0   530000.0        1980              0
# 16762          3      2007             0   449400.0        2490              0
#
# [6484 rows x 6 columns]

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Standardize the features
scaler = StandardScaler()
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

# %%
df_std = scaler.fit_transform(df[numerical_features])

# %%
pca = PCA()
df_pca = pca.fit_transform(df_std)

# %%
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained variance ratio:", explained_variance_ratio)
# Out:
# Explained variance ratio: [2.83775344e-01 1.20752954e-01 9.37885301e-02 6.93162206e-02
#  6.14652571e-02 5.03295519e-02 4.82552052e-02 4.60214680e-02
#  4.14518714e-02 3.29958748e-02 3.00546723e-02 2.55779204e-02
#  2.09966800e-02 1.65887660e-02 1.47085481e-02 1.32309776e-02
#  1.18596362e-02 9.71089347e-03 9.11962795e-03 1.29262727e-32]

# %%
cumsum_variance = np.cumsum(pca.explained_variance_ratio_)
print('Cumulative explained variance ratio:', cumsum_variance)
# Out:
# Cumulative explained variance ratio: [0.28377534 0.4045283  0.49831683 0.56763305 0.62909831 0.67942786
#  0.72768306 0.77370453 0.8151564  0.84815228 0.87820695 0.90378487
#  0.92478155 0.94137032 0.95607886 0.96930984 0.98116948 0.99088037
#  1.         1.        ]

# %%
print(df_pca[:5])
# Out:
# [[-2.79109488e+00  9.62590653e-02 -4.48135374e-01  6.22912381e-01
#   -2.10665219e-02 -1.20778398e-01 -3.85373680e-01  1.10285189e+00
#    2.08031228e-01 -2.80420954e-01  1.10040323e+00 -3.66147469e-02
#   -9.00637166e-01  1.25584902e-01  3.79698313e-01 -1.16375509e-01
#    5.90093653e-01 -1.00106406e-02 -5.39668840e-02  2.44030888e-16]
#  [-1.18330689e-01  1.66903730e+00 -8.26438725e-01  1.81858539e+00
#    6.05632556e-01  4.10597107e+00 -1.40543811e+00 -8.99108170e-03
#    1.90073719e-01  4.21619630e-01 -1.03851985e+00 -1.08169803e-02
#   -4.00129551e-01  2.27011988e-02 -3.15651208e-01  1.45549861e-01
#   -4.29047419e-01  9.55355170e-01  3.33594683e-01 -1.61488765e-14]
#  [-2.74665460e+00 -3.78321817e-01  2.90318763e-01  3.05988056e-01
#   -1.25298168e-01 -4.16244332e-01 -1.64820026e+00 -8.62599872e-01
#   -1.25489765e+00 -5.44879505e-01  7.42369468e-01  8.92510422e-03
#    5.94629754e-01  9.38798027e-02 -1.16361409e+00  9.87659193e-01
# ...

# %%
# Let's do the same, but now let's reduce to 2 components
# Perform PCA
pca = PCA(n_components = 0.90)
df_pca = pca.fit_transform(df_std)

# The transformed data is an array, convert it back into a dataframe
df_pca = pd.DataFrame(df_pca)

# Print the explained variance ratio
print('Explained variance ratio:', pca.explained_variance_ratio_)

# Print the cumulative explained variance ratio
cumsum_variance = np.cumsum(pca.explained_variance_ratio_)
print('Cumulative explained variance ratio:', cumsum_variance)

# Show the first few rows of transformed dataframe
df_pca.head()
# Out:
# Explained variance ratio: [0.28377534 0.12075295 0.09378853 0.06931622 0.06146526 0.05032955
#  0.04825521 0.04602147 0.04145187 0.03299587 0.03005467 0.02557792]
# Cumulative explained variance ratio: [0.28377534 0.4045283  0.49831683 0.56763305 0.62909831 0.67942786
#  0.72768306 0.77370453 0.8151564  0.84815228 0.87820695 0.90378487]
#          0         1         2         3         4         5         6
# 0 -2.791095  0.096259 -0.448135  0.622912 -0.021067 -0.120778 -0.385374  \
# 1 -0.118331  1.669037 -0.826439  1.818585  0.605633  4.105971 -1.405438
# 2 -2.746655 -0.378322  0.290319  0.305988 -0.125298 -0.416244 -1.648200
# 3 -1.018035  2.080815  0.470157 -1.724612  0.769268 -0.324990  1.549822
# 4 -0.350405 -1.012805 -0.033179  0.224875  0.144229 -0.212552  0.034367
#
#          7         8         9         10        11
# 0  1.102852  0.208031 -0.280421  1.100403 -0.036615
# 1 -0.008991  0.190074  0.421620 -1.038520 -0.010817
# ...

# %% [markdown]
# # feature engineering

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['price'].unique()
# Out:
# array([ 221900.,  538000.,  180000., ...,  610685., 1007500.,  402101.])

# %%
df['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13,  1], dtype=int64)

# %%
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...                      yr_built
# ...

# %%
df['log_price'] = np.log1p(df['price'])

# bathroom
df['total_bathrooms'] = df['bedrooms'] + df['bathrooms']

# sqft_living
df['log_sqft_living'] = np.log1p(df['sqft_living'])
df['log_sqft_lot'] = np.log1p(df['sqft_lot'])

# floor
df['multi_floor'] = np.where(df['floors'] > 1, 1, 0)

# waterfront$view
df['waterfront'] = df['waterfront'].astype('category')
df['view'] = df['view'].astype('category')

# year

df['renovated'] = np.where(df['yr_renovated'] > 0, 1, 0)

# feagures
selected_features = ['bedrooms', 'bathrooms', 'total_bathrooms', 'log_sqft_living', 'log_sqft_lot',
                     'grade', 'waterfront', 'view', 'multi_floor', 'renovated']

# std
numerical_features = ['bedrooms', 'bathrooms', 'total_bathrooms', 'log_sqft_living', 'log_sqft_lot', 'grade']
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# print
print(df[selected_features].head())
# Out:
#    bedrooms  bathrooms  total_bathrooms  log_sqft_living  log_sqft_lot
# 0 -0.398737  -1.447464        -1.060305        -1.123053     -0.388517  \
# 1 -0.398737   0.175607        -0.128148         0.709313     -0.113429
# 2 -1.473959  -1.447464        -1.677824        -2.127474      0.244170
# 3  0.676485   1.149449         1.048666         0.071368     -0.523948
# 4 -0.398737  -0.149007        -0.314579        -0.291522      0.007910
#
#       grade waterfront view  multi_floor  renovated
# 0 -0.558836          0    0            0          0
# 1 -0.558836          0    0            1          1
# 2 -1.409587          0    0            0          0
# 3 -0.558836          0    0            0          0
# 4  0.291916          0    0            0          0

# %% [markdown]
# # In conclusion, the better the view from the location of the house, or the higher the coefficient, the higher the house price
# # According to the coefficients, the main drives are : number of bedrroms, bathrooms, waterfront view, the view of property, condition of house,built_year
# business executive
# # if the house has a good grade, the average price of a house will increase by more than $7142; If the houe; if a house has a good view, the average of price will increase more than $60000; if a house has a good condition, the average of price of a house will increase by $50000. Therefore, we can know that the price of a house needs to consider various variables, and each variable is very important. Especially the quality of housing is particularly important.
